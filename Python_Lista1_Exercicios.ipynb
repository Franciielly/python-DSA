# %% [markdown]
# <a href="https://colab.research.google.com/github/Franciielly/python-DSA/blob/main/Python_Lista1_Exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- Trabalho Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Fundamentos de Linguagem Python - Do Básico a Aplicações de IA</font>
# # <font color='blue'>Lista 1 de Exercícios</font>

# %% [markdown]
# #### Exercício 1
#
# Escreva um programa que peça ao usuário para digitar seu nome e, em seguida, imprima uma mensagem de boas-vindas com o nome fornecido.

# %%
nome = input("Digite seu nome: ")
print(f"Bem-vindo {nome}")
# Out:
# Digite seu nome: francielly
# Bem-vindo francielly

# %% [markdown]
# #### Exercício 2
#
# Crie duas variáveis, numero1 e numero2, e atribua a elas valores inteiros. Calcule a soma, subtração, multiplicação e divisão dessas variáveis e imprima os resultados.

# %%
numero1 = int(input("Digite o número 1: "))
numero2 = int(input("Digite o número 2: "))

soma = numero1 + numero2
sub = numero1 - numero2
mult = numero1 * numero2
div = numero1/numero2

print(f"Soma = {soma}")
print(f"Subtração = {sub}")
print(f"Multiplicação = {mult}")
print(f"Divisão = {div}")
# Out:
# Digite o número 1: 10
# Digite o número 2: 3
# Soma = 13
# Subtração = 7
# Multiplicação = 30
# Divisão = 3.3333333333333335

# %% [markdown]
# #### Exercício 3
#
# Qual é a principal diferença entre uma variável de escopo local e uma de escopo global?

# %%
def soma(n1, n2):
  soma = n1 + n2  #variavel local:criada dentro da função, após o uso ela "desaparece"
  return soma

n1 = int(input("Digite o número 1: "))
n2 = 5 #variável global: criada fora da função e acessível dentro dela

resultado = soma(n1, n2)
print(f"O resultado é {resultado}")
# Out:
# Digite o número 1: 3
# O resultado é 8

# %% [markdown]
# #### Exercício 4
#
# Crie uma variável chamada saldo com o valor 500.50 (float). Em seguida, crie uma variável saque com o valor 200.25 (float). Subtraia o saque do saldo e imprima o saldo final formatado para duas casas decimais.

# %%
saldo = 500.50
saque = 200.25

resta = saldo - saque

print(f"Resta em sua conta R${resta:.2f}")
# Out:
# Resta em sua conta R$300.25

# %% [markdown]
# #### Exercício 5
#
# Declare uma variável booleana chamada **tem_carteira_de_motorista** e atribua a ela o valor True. Imprima uma mensagem que diga "Pode dirigir" se a variável for verdadeira e "Não pode dirigir" caso contrário.

# %%
tem_carteira_de_motorista = True

if tem_carteira_de_motorista:
  print("Pode dirigir")
else:
  print("Não pode dirigir")
# Out:
# Pode dirigir

# %% [markdown]
# #### Exercício 6
#
# Crie duas variáveis:
#
# - idade_ana = 25
# - idade_beto = 30
#
# Use operadores de comparação para verificar se a idade de Ana é menor que a de Beto e imprima o resultado booleano.

# %%
idade_ana = 25
idade_beto = 30

print(idade_ana < idade_beto)
# Out:
# True

# %% [markdown]
# #### Exercício 7
#
# Receba um número inteiro do usuário e use o operador de módulo (%) para verificar se o número é par ou ímpar. Imprima o resultado.
#
# Obs: Não estudamos ainda os condicionais, mas pesquise se necessário e tente resolver.

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 0:
  print(f"O número {numero} é par")
else:
  print(f"O número {numero} é impar")
# Out:
# Digite um número: 14
# O número 14 é par

# %% [markdown]
# #### Exercício 8
#
# Crie duas variáveis booleanas:
#
# - chovendo = True
# - guarda_chuva = False
#
# Use operadores lógicos para verificar se uma pessoa vai se molhar (se está chovendo E ela não tem guarda-chuva).

# %%
chovendo = True
guarda_chuva = False

print(chovendo and not guarda_chuva)
# Out:
# True

# %% [markdown]
# #### Exercício 9
#
# Calcule a potência de 2 elevado a 10 e imprima o resultado.

# %%
n = int(input("Digite a base: "))
p = int(input("Digite o expoente: "))

resultado = n**p

print(f"{n} ^ {p} = {resultado}")
# Out:
# Digite a base: 2
# Digite o expoente: 2
# 2 ^ 2 = 4

# %% [markdown]
# #### Exercício 10
#
# Converta a string "2026" para um tipo inteiro e armazene-a em uma variável chamada ano. Em seguida, some 1 a essa variável e imprima o novo ano.

# %%
anoS = "2026"
type(anoS)

ano = int(anoS) + 1
print(f"Ano Novo: {ano}")
# Out:
# Ano Novo: 2027

# %% [markdown]
# #### Exercício 11
#
# Crie a string:
#
# frase = "   Python é uma linguagem poderosa e estou aprendendo com a DSA   ".
#
# Remova os espaços em branco do início e do fim da string e imprima a nova string.

# %%
frase = " Python é uma linguagem poderosa e estou aprendendo com a DSA "
fraseNova = frase.strip()

print(f"Antiga frase: {frase}")
print(f"Nova frase: {fraseNova}")
# Out:
# Antiga frase:  Python é uma linguagem poderosa e estou aprendendo com a DSA
# Nova frase: Python é uma linguagem poderosa e estou aprendendo com a DSA

# %% [markdown]
# #### Exercício 12
#
# Na string do exercício anterior (já sem os espaços), converta toda a frase para letras maiúsculas.

# %%
fraseNova = fraseNova.upper()
print(fraseNova)
# Out:
# PYTHON É UMA LINGUAGEM PODEROSA E ESTOU APRENDENDO COM A DSA

# %% [markdown]
# #### Exercício 13
#
# Ainda usando a mesma string, substitua a palavra "poderosa" por "incrível".

# %%
fraseNova = fraseNova.replace("PODEROSA", "incrível")
print(fraseNova)
# Out:
# PYTHON É UMA LINGUAGEM incrível E ESTOU APRENDENDO COM A DSA

# %% [markdown]
# #### Exercício 14
#
# Verifique e imprima o número total de caracteres na string frase (após as modificações dos exercícios anteriores).

# %%
print(f"Número total de caracteres: {len(fraseNova)}")
# Out:
# Número total de caracteres: 60

# %% [markdown]
# #### Exercício 15
#
# Use fatiamento (slicing) para extrair e imprimir apenas a palavra "Python" da string frase.

# %%
print(f"Palavra Python: {fraseNova[0:6]}")
# Out:
# Palavra Python: PYTHON

# %% [markdown]
# #### Exercício 16
#
# Crie uma lista chamada compras com os seguintes itens: "arroz", "feijão", "macarrão", "carne". Imprima a lista.

# %%
lista_compras = ["arroz", "feijão", "macarrão", "carne"]
print(f"Lista de compras: {lista_compras}")
# Out:
# Lista de compras: ['arroz', 'feijão', 'macarrão', 'carne']

# %% [markdown]
# #### Exercício 17
#
# Adicione o item "leite" ao final da lista compras e imprima a lista atualizada.

# %%
lista_compras.append("leite")
print(f"Lista atualizad: {lista_compras}")
# Out:
# Lista atualizad: ['arroz', 'feijão', 'macarrão', 'carne', 'leite']

# %% [markdown]
# #### Exercício 18
#
# Acesse e imprima o segundo item da lista compras.

# %%
print(f"Segundo item da lista: {lista_compras[1]}")
# Out:
# Segundo item da lista: feijão

# %% [markdown]
# #### Exercício 19
#
# Remova o item "macarrão" da lista compras e imprima a lista final.

# %%
lista_compras.remove("macarrão")
print(f"Lista atualizada: {lista_compras}")
# Out:
# Lista atualizada: ['arroz', 'feijão', 'carne', 'leite']

# %% [markdown]
# #### Exercício 20
#
# Crie uma lista de números de 1 a 5. Use uma função para calcular e imprimir o tamanho (número de elementos) dessa lista.

# %%
lista_numerica =[1,2,3,4,5]

def tamanho(lista_numerica):
  tamanho = len(lista_numerica)
  return tamanho

tamanho_lista = tamanho(lista_numerica)
print(f"A lista tem tamanho: {tamanho_lista}")
# Out:
# A lista tem tamanho: 5

# %% [markdown]
# #### Exercício 21
#
# Crie uma tupla chamada meses com os três primeiros meses do ano: "Janeiro", "Fevereiro", "Março".

# %%
meses = ("Janeiro", "Fevereiro", "Março")
type(meses)
# Out:
# tuple

# %% [markdown]
# #### Exercício 22
#
# Tente adicionar o mês "Abril" à tupla meses. O que acontece? Explique o resultado.

# %%
# Para resolver este exercício precisamos primeiro transformar a tupla em lista, pois a tupla é imutável

mesesLista = list(meses)
mesesLista.append("Abril")
meses = tuple(mesesLista)
print(f"Meses = {meses} tipo = {type(meses)}")
# Out:
# Meses = ('Janeiro', 'Fevereiro', 'Março', 'Abril') tipo = <class 'tuple'>

# %% [markdown]
# #### Exercício 23
#
# Acesse e imprima o primeiro mês da tupla meses.

# %%
print(f"Primeiro mês = {meses[0]}")
# Out:
# Primeiro mês = Janeiro

# %% [markdown]
# #### Exercício 24
#
# Crie um dicionário chamado filme com as seguintes chaves e valores:
#
# - titulo = "O Poderoso Chefão",
# - ano = 1972
# - diretor = "Francis Ford Coppola"

# %%
filme = {
    "titulo" : "O Poderoso Chefão",
    "ano" : "1972",
    "diretor" : "Francis Ford Coppola"
}

# %% [markdown]
# #### Exercício 25
#
# Acesse e imprima o ano de lançamento do filme a partir do dicionário.

# %%
print(f"Ano de lançamento: {filme.get('ano')}")
# Out:
# Ano de lançamento: 1972

# %% [markdown]
# #### Exercício 26
#
# Adicione uma nova chave genero com o valor "Drama" ao dicionário filme e imprima o dicionário completo.

# %%
filme ['genero'] = "Drama"
print(f"Dicionário do filme {filme}")
# Out:
# Dicionário do filme {'titulo': 'O Poderoso Chefão', 'ano': '1972', 'diretor': 'Francis Ford Coppola', 'genero': 'Drama'}

# %% [markdown]
# #### Exercício 27
#
# Modifique o valor da chave ano para 1973 e imprima o dicionário atualizado.

# %%
filme ['ano'] = 1973
print(f"Dicionário atualizado: {filme}")
# Out:
# Dicionário atualizado: {'titulo': 'O Poderoso Chefão', 'ano': 1973, 'diretor': 'Francis Ford Coppola', 'genero': 'Drama'}

# %% [markdown]
# #### Exercício 28
#
# Crie uma lista com os seguintes números: [1, 2, 2, 3, 4, 4, 5, 1]. Use um conjunto para remover os números duplicados e imprima o resultado.

# %%
lista = [1,2,2,3,4,4,5,1]
lista_conjunto = set(lista)

print(lista_conjunto)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# #### Exercício 29
#
# Crie dois conjuntos:
#
# - set_a = {1, 2, 3, 4}
# - set_b = {3, 4, 5, 6}
#
# Encontre e imprima a interseção entre os dois conjuntos (os elementos que estão em ambos).

# %%
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}

setAB = set_a.intersection(set_b)

print(f"Intersecção: {setAB}")
# Out:
# Intersecção: {3, 4}

# %% [markdown]
# #### Exercício 30
#
# Escreva um programa que peça ao usuário para digitar sua altura em metros (ex: 1.75) e seu peso em quilogramas (ex: 68.5). Calcule o Índice de Massa Corporal (IMC) usando a fórmula IMC = peso / (altura * altura) e imprima o resultado formatado com duas casas decimais.

# %%
altura = float(input("Digite sua altura: "))
peso = float(input("Digite seu peso: "))

imc = peso/(altura * altura)

print(f"Seu IMC é = {imc:.2f}")
# Out:
# Digite sua altura: 1.70
# Digite seu peso: 65
# Seu IMC é = 22.49

# %% [markdown]
# # Fim
